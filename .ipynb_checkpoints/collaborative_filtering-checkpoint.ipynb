# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

book_preferences = {
    'Jean':{
        'Humain Trop Humain': 3.0,
        'Genealogie du mal': 4.0,
        'Harry Potter': 6.8,
        'Le Prince': 2.9,
        'Discours de la methode': 5.0
    },
    
    'Molly':{
        'Humain Trop Humain': 6.0,
        'Genealogie du mal': 2.0,
        'Harry Potter': 4.8,
        'Le Prince': 5.9,
        'Discours de la methode': 9.0
    },
    
    'Jacques':{
        'Humain Trop Humain': 8.0,
        'Genealogie du mal': 2.0,
        'Harry Potter': 6.8,
        'Le Prince': 2.9,
        'Discours de la methode': 5.0
    },
    
    'Gerard':{
        'Humain Trop Humain': 3.0,
        'Genealogie du mal': 4.0,
        'Harry Potter': 6.8,
        'Medecine humaine': 8.9,
        'Discours de la methode': 5.0
    },
    
    'Dorothe':{
        'Humain Trop Humain': 1.0,
        'Genealogie du mal': 3.0,
        'Harry Potter': 7.8,
        'Le Prince': 2.9,
        'Discours de la methode': 6.0
    },
    
    'Jacob':{
        'Humain Trop Humain': 4.0,
        'Genealogie du mal': 5.0,
        'Harry Potter': 7.8,
        'Le Prince': 2.9,
        'Discours de la methode': 5.0
    },
    
    'Anis':{
        'Humain Trop Humain': 4.0,
        'Genealogie du mal': 1.0,
        'Harry Potter': 6.8,
        'Le Prince': 8.9,
        'Discours de la methode': 5.0
    },
    
    'Ose':{
        'Humain Trop Humain': 7.8,
        'Genealogie du mal': 3.4,
        'Harry Potter': 7.1,
        'Le Prince': 4.9,
        'Discours de la methode': 3.0
    },
    
    'Issac':{
        'Humain Trop Humain': 5.0,
        'Genealogie du mal': 2.0,
        'Harry Potter': 8.8,
        'Le Prince': 9.9,
        'Discours de la methode': 1.0
    },
    
    'Drum':{
        'Humain Trop Humain': 4.0,
        'Genealogie du mal': 6.0,
        'Harry Potter': 7.8,
        'Le Prince': 3.9,
        'Discours de la methode': 4.0
    },
    
    
}

# %%
#let's know what score for 'Humain trop Humain' and 'Genealogie du mal'

data_tuple = [
    (i, book_preferences[i]['Humain Trop Humain'],\
     book_preferences[i]['Genealogie du mal'])
for i in book_preferences]

data_map = pd.DataFrame(data=data_tuple, columns=['user','humain_nietschze', 'genealogie_nietschze'])

plt.scatter(data_map.humain_nietschze, data_map.genealogie_nietschze)
plt.xlabel('Humain trop Humain')
plt.ylabel('Genealogie du mal')

for i, txt in enumerate(data_map.user):
    plt.annotate(txt, (data_map.humain_nietschze[i], data_map.genealogie_nietschze[i]))
    
plt.show()
